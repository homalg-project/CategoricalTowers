# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.10
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
DigraphOfKnownDoctrines( )
# Out:
# GAP: <immutable digraph with 86 vertices, 149 edges>

# %%
Abel = DummyCategoryInDoctrines( "IsAbelianCategory" )
# Out:
# GAP: DummyCategoryInDoctrines( [ "IsAbelianCategory" ] )

# %%
Display( Abel )
# Out:
# A CAP category with name DummyCategoryInDoctrines( [ "IsAbelianCategory" ] ):
#
# 33 primitive operations were used to derive 309 operations for this category which algorithmically
# * IsAbelianCategory

# %%
ListPrimitivelyInstalledOperationsOfCategory( Abel )
# Out:
# GAP: [ "AdditionForMorphisms", "AdditiveInverseForMorphisms", "CokernelColift", "CokernelObject", "CokernelProjection", "ColiftAlongEpimorphism", "DirectSum", "IdentityMorphism", "InjectionOfCofactorOfDirectSum", "InverseOfMorphismFromCoimageToImage", "IsCongruentForMorphisms", "IsEqualForMorphisms", "IsEqualForObjects", "IsWellDefinedForMorphisms", "IsWellDefinedForObjects", "IsZeroForMorphisms", "KernelEmbedding", "KernelLift", "KernelObject", "LiftAlongMonomorphism", "MorphismConstructor", "MorphismDatum", "ObjectConstructor", "ObjectDatum", "PreCompose", "ProjectionInFactorOfDirectSum", "SubtractionForMorphisms", "UniversalMorphismFromDirectSum", "UniversalMorphismFromZeroObject", "UniversalMorphismIntoDirectSum", "UniversalMorphismIntoZeroObject", "ZeroMorphism", "ZeroObject" ]
