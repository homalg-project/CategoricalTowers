# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.3
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FreydCategoriesForCAP" )

# %%
LoadPackage( "SubcategoriesForCAP" )

# %%
LoadPackage( "Locales" )

# %%
LoadPackage( "LazyCategories" )

# %%
Q = HomalgFieldOfRationalsInSingular( )
# Out:
# GAP: Q

# %%
R = Q["x,y"]
# Out:
# GAP: Q[x,y]

# %%
K = HomalgMatrix( "[ x, -x ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
J = HomalgMatrix( "[ x, y ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
I = KroneckerMat( K, J )
# Out:
# GAP: <An unevaluated 4 x 1 matrix over an external ring>

# %%
P = CategoryOfRows( R )
# Out:
# GAP: Rows( Q[x,y] )

# %%
P = LazyCategory( P, show_evaluation = true, primitive_operations = true )
# Out:
# GAP: LazyCategory( Rows( Q[x,y] ) )

# %%
I = I / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( I, "I" ); SetLabel( Source( I ), "R^i" )

# %%
R = Target( I )
# Out:
# GAP: <An evaluated object in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( R, "R" )

# %%
J = J / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( J, "J" ); SetLabel( Source( J ), "R^j" )

# %%
K = K / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
S = SliceCategoryOverTensorUnit( P )
# Out:
# GAP: SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) )

# %%
L = PosetOfCategory( S )
# Out:
# GAP: PosetOfCategory( SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) ) )

# %%
I = I / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCatego\
# ry( Rows( Q[x,y] ) )>

# %%
J = J / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCatego\
# ry( Rows( Q[x,y] ) )>

# %%
K = K / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCatego\
# ry( Rows( Q[x,y] ) )>

# %%
IqJ = InternalHom( J, I )
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <A morphism in LazyCategory( Rows( Q\
# [x,y] ) )>

# %%
Visualize( UnderlyingMorphism( UnderlyingObject( IqJ ) ) )

# %%
K == IqJ
# Out:
# 1.      -> evaluating in Rows( Q[x,y] ).........................: ProjectionOf\
# BiasedWeakFiberProductWithGivenBiasedWeakFiberProduct
# 2.       -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 3.       -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 4.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 5.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 6.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 7.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 8.         -> evaluating in Rows( Q[x,y] ).........................: LiftAlong\
# Monomorphism
# 9.         -> evaluating in Rows( Q[x,y] ).........................: LeftUnito\
# rWithGivenTensorProduct
# 10
#  .        -> evaluating in Rows( Q[x,y] ).........................: TensorUnit
# 10.        <- evaluated in Rows( Q[x,y] ).........................: TensorUnit
# 11
#  .        -> evaluating in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 11
#  .        <- evaluated in Rows( Q[x,y] ).........................: TensorProdu\
# ctOnObjects
# 9.         <- evaluated in Rows( Q[x,y] ).........................: LeftUnitor\
# WithGivenTensorProduct
# 12
#  .        -> evaluating in Rows( Q[x,y] ).........................: IdentityMo\
# rphism
# 12
#  .        <- evaluated in Rows( Q[x,y] ).........................: IdentityMor\
# phism
# 8.         <- evaluated in Rows( Q[x,y] ).........................: LiftAlongM\
# onomorphism
# 13
#  .        -> evaluating in Rows( Q[x,y] ).........................: TensorProd\
# uctOnMorphismsWithGivenTensorProducts
# 14
#  .        -> evaluating in Rows( Q[x,y] ).........................: Coevaluati\
# onForDualWithGivenTensorProduct
# 15
#  .        -> evaluating in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 16
#  .         -> evaluating in Rows( Q[x,y] ).........................: DualOnObj\
# ects
# 16
#  .         <- evaluated in Rows( Q[x,y] ).........................: DualOnObje\
# cts
# 15
#  .        <- evaluated in Rows( Q[x,y] ).........................: TensorProdu\
# ctOnObjects
# 14
#  .        <- evaluated in Rows( Q[x,y] ).........................: Coevaluatio\
# nForDualWithGivenTensorProduct
# 17
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 17
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 13
#  .        <- evaluated in Rows( Q[x,y] ).........................: TensorProdu\
# ctOnMorphismsWithGivenTensorProducts
# 7.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 18
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnMorphismsWithGivenTensorProducts
# 19
#  .         -> evaluating in Rows( Q[x,y] ).........................: BraidingW\
# ithGivenTensorProducts
# 20
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 20
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 19
#  .         <- evaluated in Rows( Q[x,y] ).........................: BraidingWi\
# thGivenTensorProducts
# 21
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 21
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 18
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnMorphismsWithGivenTensorProducts
# 6.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 22
#  .         -> evaluating in Rows( Q[x,y] ).........................: Associato\
# rLeftToRightWithGivenTensorProducts
# 23
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 23
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnObjects
# 22
#  .         <- evaluated in Rows( Q[x,y] ).........................: Associator\
# LeftToRightWithGivenTensorProducts
# 5.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 24
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnMorphismsWithGivenTensorProducts
# 25
#  .         -> evaluating in Rows( Q[x,y] ).........................: IdentityM\
# orphism
# 25
#  .         <- evaluated in Rows( Q[x,y] ).........................: IdentityMo\
# rphism
# 26
#  .         -> evaluating in Rows( Q[x,y] ).........................: BraidingW\
# ithGivenTensorProducts
# 26
#  .         <- evaluated in Rows( Q[x,y] ).........................: BraidingWi\
# thGivenTensorProducts
# 24
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnMorphismsWithGivenTensorProducts
# 4.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 27
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnMorphismsWithGivenTensorProducts
# 28
#  .         -> evaluating in Rows( Q[x,y] ).........................: DualOnMor\
# phismsWithGivenDuals
# 28
#  .         <- evaluated in Rows( Q[x,y] ).........................: DualOnMorp\
# hismsWithGivenDuals
# 27
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnMorphismsWithGivenTensorProducts
# 3.       <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 29
#  .         -> evaluating in Rows( Q[x,y] ).........................: TensorPro\
# ductOnMorphismsWithGivenTensorProducts
# 30
#  .         -> evaluating in Rows( Q[x,y] ).........................: DualOnMor\
# phismsWithGivenDuals
# 31
#  .         -> evaluating in Rows( Q[x,y] ).........................: DualOnObj\
# ects
# 31
#  .         <- evaluated in Rows( Q[x,y] ).........................: DualOnObje\
# cts
# 30
#  .         <- evaluated in Rows( Q[x,y] ).........................: DualOnMorp\
# hismsWithGivenDuals
# 32
#  .          -> evaluating in Rows( Q[x,y] ).........................: TensorPr\
# oductOnObjects
# 32
#  .          <- evaluated in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 29
#  .         <- evaluated in Rows( Q[x,y] ).........................: TensorProd\
# uctOnMorphismsWithGivenTensorProducts
# 2.       <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 33
#  .          -> evaluating in Rows( Q[x,y] ).........................: TensorPr\
# oductOnMorphismsWithGivenTensorProducts
# 34
#  .          -> evaluating in Rows( Q[x,y] ).........................: TensorPr\
# oductOnObjects
# 34
#  .          <- evaluated in Rows( Q[x,y] ).........................: TensorPro\
# ductOnObjects
# 35
#  .          -> evaluating in Rows( Q[x,y] ).........................: DualOnMo\
# rphismsWithGivenDuals
# 36
#  .          -> evaluating in Rows( Q[x,y] ).........................: Identity\
# Morphism
# 36
#  .          <- evaluated in Rows( Q[x,y] ).........................: IdentityM\
# orphism
# 35
#  .          <- evaluated in Rows( Q[x,y] ).........................: DualOnMor\
# phismsWithGivenDuals
# 33
#  .          <- evaluated in Rows( Q[x,y] ).........................: TensorPro\
# ductOnMorphismsWithGivenTensorProducts
# 37
#  .          -> evaluating in Rows( Q[x,y] ).........................: BiasedWe\
# akFiberProduct
# 37
#  .          <- evaluated in Rows( Q[x,y] ).........................: BiasedWea\
# kFiberProduct
# 1.      <- evaluated in Rows( Q[x,y] ).........................: ProjectionOfB\
# iasedWeakFiberProductWithGivenBiasedWeakFiberProduct
# true
