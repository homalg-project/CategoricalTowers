# %% [markdown]
# ## The image of a polynomial map
#
# The following polynomial map
# $$
#   \varphi:
#   \begin{cases} \mathbb{Q}^6 &\to \mathbb{Q}^4,\\
#   (a,b,c,d,e,f) &\mapsto (y_1,y_2,y_3,y_4) := (ace+bdf, acf+bde, ade+bcf, bce+adf)
#   \end{cases}
# $$
# considered as Example 5.1 in [HMS18]. It represents the Cavender–Farris–Neyman model, a type of group-based model, which is aspecial Markov process on trees.
#
# [HMS18] Corey Harris, Mateusz Michałek, and Emre Can Sertöz, Computing images of polynomial maps, (arXiv:1801.00827), 2018.

# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.8
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "ZariskiFrames" )

# %%
UseSystemSingular(false)
# Out:
# true

# %%
ℚ = HomalgFieldOfRationalsInSingular( )
# Out:
# GAP: Q

# %%
B = ℚ["y1..4"]
# Out:
# GAP: Q[y1,y2,y3,y4]

# %%
T = ℚ["a,b,c,d,e,f"]
# Out:
# GAP: Q[a,b,c,d,e,f]

# %%
ϕ = RingMap( HomalgMatrix( "[ a*c*e+b*d*f, b*d*e+a*c*f, a*d*e+b*c*f, b*c*e+a*d*f ]", 4, 1, T ),  B, T );

# %%
Display( ϕ )
# Out:
# Q[a,b,c,d,e,f]
#   ^
#   |
# [ a*c*e+b*d*f, b*d*e+a*c*f, a*d*e+b*c*f, b*c*e+a*d*f ]
#   |
#   |
# Q[y1,y2,y3,y4]

# %%
im = ConstructibleImage( ϕ )
# Out:
# GAP: ( V_{Q[y1,y2,y3,y4]}( I1 ) \ V_{Q[y1,y2,y3,y4]}( J1_1 ) \ .. \ V_{Q[y1,y2,y3,y4]}( J1_4 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I2 ) \ V_{Q[y1,y2,y3,y4]}( J2_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I3 ) \ V_{Q[y1,y2,y3,y4]}( J3_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I4 ) \ V_{Q[y1,y2,y3,y4]}( J4_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I5 ) \ V_{Q[y1,y2,y3,y4]}( J5_1 ) )

# %%
FactorizeObject( im )
# Out:
# GAP: ( V_{Q[y1,y2,y3,y4]}( I1 ) \ V_{Q[y1,y2,y3,y4]}( J1_1 ) \ .. \ V_{Q[y1,y2,y3,y4]}( J1_4 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I2 ) \ V_{Q[y1,y2,y3,y4]}( J2_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I3 ) \ V_{Q[y1,y2,y3,y4]}( J3_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I4 ) \ V_{Q[y1,y2,y3,y4]}( J4_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I5 ) \ V_{Q[y1,y2,y3,y4]}( J5_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I6 ) \ V_{Q[y1,y2,y3,y4]}( J6_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I7 ) \ V_{Q[y1,y2,y3,y4]}( J7_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I8 ) \ V_{Q[y1,y2,y3,y4]}( J8_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I9 ) \ V_{Q[y1,y2,y3,y4]}( J9_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I10 ) \ V_{Q[y1,y2,y3,y4]}( J10_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I11 ) \ V_{Q[y1,y2,y3,y4]}( J11_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I12 ) \ V_{Q[y1,y2,y3,y4]}( J12_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I13 ) \ V_{Q[y1,y2,y3,y4]}( J13_1 ) )

# %%
Display( im )
# Out:
# ( V( <> )
#
# \ V( <y1+y2+y3+y4> )
#
# \ V( <y1+y2-y3-y4> )
#
# \ V( <y1-y2-y3+y4> )
#
# \ V( <y1-y2+y3-y4> ) )
#
# ∪
#
# ( { V( <y3+y4,y1+y2+y3+y4> ) ∪ V( <y2+y4,y1+y2+y3+y4> ) ∪ V( <y2+y3,y1+y2+y3+y4> ) }
#
# \ ∅ )
#
# ∪
#
# ( { V( <y3+y4,y1+y2-y3-y4> ) ∪ V( <y2-y4,y1+y2-y3-y4> ) ∪ V( <y2-y3,y1+y2-y3-y4> ) }
#
# \ ∅ )
#
# ∪
#
# ( { V( <y3-y4,y1-y2-y3+y4> ) ∪ V( <y2-y4,y1-y2-y3+y4> ) ∪ V( <y2+y3,y1-y2-y3+y4> ) }
#
# \ ∅ )
#
# ∪
#
# ( { V( <y2+y4,y1-y2+y3-y4> ) ∪ V( <y3-y4,y1-y2+y3-y4> ) ∪ V( <y2-y3,y1-y2+y3-y4> ) }
#
# \ ∅ )

# %%
Visualize( im )

# %%
Visualize( im, all = true )

# %%
imf = ConstructibleImage( ϕ, freeness = true )
# Out:
# GAP: ( V_{Q[y1,y2,y3,y4]}( I1 ) \ V_{Q[y1,y2,y3,y4]}( J1_1 ) \ .. \ V_{Q[y1,y2,y3,y4]}( J1_4 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I2 ) \ V_{Q[y1,y2,y3,y4]}( J2_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I3 ) \ V_{Q[y1,y2,y3,y4]}( J3_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I4 ) \ V_{Q[y1,y2,y3,y4]}( J4_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I5 ) \ V_{Q[y1,y2,y3,y4]}( J5_1 ) )

# %%
FactorizeObject( imf )
# Out:
# GAP: ( V_{Q[y1,y2,y3,y4]}( I1 ) \ V_{Q[y1,y2,y3,y4]}( J1_1 ) \ .. \ V_{Q[y1,y2,y3,y4]}( J1_4 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I2 ) \ V_{Q[y1,y2,y3,y4]}( J2_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I3 ) \ V_{Q[y1,y2,y3,y4]}( J3_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I4 ) \ V_{Q[y1,y2,y3,y4]}( J4_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I5 ) \ V_{Q[y1,y2,y3,y4]}( J5_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I6 ) \ V_{Q[y1,y2,y3,y4]}( J6_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I7 ) \ V_{Q[y1,y2,y3,y4]}( J7_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I8 ) \ V_{Q[y1,y2,y3,y4]}( J8_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I9 ) \ V_{Q[y1,y2,y3,y4]}( J9_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I10 ) \ V_{Q[y1,y2,y3,y4]}( J10_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I11 ) \ V_{Q[y1,y2,y3,y4]}( J11_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I12 ) \ V_{Q[y1,y2,y3,y4]}( J12_1 ) ) ∪ ( V_{Q[y1,y2,y3,y4]}( I13 ) \ V_{Q[y1,y2,y3,y4]}( J13_1 ) )

# %%
Display( imf )
# Out:
# V( <> ) \ V( <y1+y2+y3+y4> ) \ V( <y1+y2-y3-y4> ) \ V( <y1-y2+y3-y4> ) \ V( <y1-y2-y3+y4> )
#
# ∪
#
# { V( <y3+y4,y1+y2+y3+y4> ) ∪ V( <y2+y4,y1+y2+y3+y4> ) ∪ V( <y2+y3,y1+y2+y3+y4> ) } \ ∅
#
# ∪
#
# { V( <y3+y4,y1+y2-y3-y4> ) ∪ V( <y2-y4,y1+y2-y3-y4> ) ∪ V( <y2-y3,y1+y2-y3-y4> ) } \ ∅
#
# ∪
#
# { V( <y2+y4,y1-y2+y3-y4> ) ∪ V( <y3-y4,y1-y2+y3-y4> ) ∪ V( <y2-y3,y1-y2+y3-y4> ) } \ ∅
#
# ∪
#
# { V( <y3-y4,y1-y2-y3+y4> ) ∪ V( <y2-y4,y1-y2-y3+y4> ) ∪ V( <y2+y3,y1-y2-y3+y4> ) } \ ∅

# %%
imf == im
# Out:
# true

# %%
Visualize( imf )

# %%
Visualize( imf, all = true )
