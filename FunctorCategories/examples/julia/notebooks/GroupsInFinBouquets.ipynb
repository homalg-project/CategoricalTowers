# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.3
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
Display( FinBouquets )
# Out:
# A CAP category with name FinBouquets:
#
# 52 primitive operations were used to derive 356 operations for this category which algorithmically
# * IsCategoryWithDecidableColifts
# * IsCategoryWithDecidableLifts
# * IsEquippedWithHomomorphismStructure
# * IsSymmetricMonoidalCategory
# * IsElementaryTopos
# and furthermore mathematically
# * IsSymmetricMonoidalCategoryStructureGivenByDirectProduct

# %%
FinBouquets.P
# Out:
# GAP: <A projective object in FinBouquets>

# %%
FinBouquets.L
# Out:
# GAP: <A projective object in FinBouquets>

# %%
T = TerminalObject( FinBouquets )
# Out:
# GAP: <An object in FinBouquets>

# %%
InitialObject( FinBouquets )
# Out:
# GAP: <An object in FinBouquets>

# %%
Ω = SubobjectClassifier( FinBouquets )
# Out:
# GAP: <An object in FinBouquets>

# %%
SomeProjectiveObject( Ω )
# Out:
# GAP: <An object in FinBouquets>

# %%
Ω2 = DirectProduct( Ω, Ω )
# Out:
# GAP: <An object in FinBouquets>

# %%
HomStructure( Ω2, Ω )
# Out:
# GAP: |1275|

# %%
homs = MorphismsOfExternalHom( Ω2, Ω );

# %%
p1 = ProjectionInFactorOfDirectProduct( [ Ω, Ω ], 1 )
# Out:
# GAP: <A morphism in FinBouquets>

# %%
p2 = ProjectionInFactorOfDirectProduct( [ Ω, Ω ], 2 )
# Out:
# GAP: <A morphism in FinBouquets>

# %%
Position( homs, p1 )
# Out:
# 715

# %%
Position( homs, p2 )
# Out:
# 1156

# %%
assoc = Filtered( homs, mult -> AssociativitiyLawOfMonoid( FinBouquets, Ω, mult ) );

# %%
Length( assoc )
# Out:
# 61

# %%
units = MorphismsOfExternalHom( T, Ω )
# Out:
# GAP: [ <A morphism in FinBouquets>, <A morphism in FinBouquets>, <A morphism in FinBouquets> ]

# %%
List( units, IsMonomorphism )
# Out:
# GAP: [ true, true, true ]

# %%
cart = Cartesian( units, assoc );

# %%
left = Filtered( cart, pair -> LeftUnitLawOfMonoid( FinBouquets, Ω, pair[1], pair[2] ) );

# %%
Length( left )
# Out:
# 25

# %%
right = Filtered( left, pair -> RightUnitLawOfMonoid( FinBouquets, Ω, pair[1], pair[2] ) );

# %%
Length( right )
# Out:
# 14

# %%
Hmon = CategoryOfHopfMonoids( FinBouquets )
# Out:
# GAP: CategoryOfHopfMonoids( FinBouquets )

# %%
Bimon = AssociatedCategoryOfBimonoids( Hmon )
# Out:
# GAP: CategoryOfBimonoids( FinBouquets )

# %%
Mon = AssociatedCategoryOfMonoids( Bimon )
# Out:
# GAP: CategoryOfMonoids( FinBouquets )

# %%
t = UniversalMorphismIntoTerminalObject( Ω )
# Out:
# GAP: <A morphism in FinBouquets>

# %%
Δ = CartesianDiagonal( Ω, 2 )
# Out:
# GAP: <A morphism in FinBouquets>

# %%
bimonoids = List( right, pair -> Bimonoid( Bimon, Triple( Ω, pair[1], pair[2] ) / Mon, t, Δ ) );

# %%
Length( bimonoids )
# Out:
# 14

# %%
ForAll( bimonoids, IsWellDefined )
# Out:
# true

# %%
isos = Filtered( MorphismsOfExternalHom( Ω, Ω ), IsIsomorphism )
# Out:
# GAP: [ <An isomorphism in FinBouquets>, <An isomorphism in FinBouquets> ]

# %%
cart2 = Cartesian( bimonoids, isos );

# %%
left2 = Filtered( cart2, pair -> LeftAntipodeLawOfHopfMonoid( Bimon, pair[1], pair[2] ) );

# %%
Length( left2 )
# Out:
# 0

# %%
right2 = Filtered( left2, pair -> RightAntipodeLawOfHopfMonoid( Bimon, pair[1], pair[2] ) );

# %%
Length( right2 )
# Out:
# 0

# %%
groups = List( right2, pair -> HopfMonoid( Hmon, pair[1], pair[2] ) )
# Out:
# GAP: [  ]

# %%
Length( groups )
# Out:
# 0

# %%
ForAll( groups, IsWellDefined )
# Out:
# true
