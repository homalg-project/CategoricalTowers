# %% [markdown]
# This notebook examines the following [MO answer](https://mathoverflow.net/a/512590/10355):

# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.13
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
q = RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" )
# Out:
# GAP: q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]

# %%
P = FreeCategory( q )
# Out:
# GAP: FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) )

# %%
Q = HomalgFieldOfRationals( )
# Out:
# GAP: Q

# %%
L = Q[P]
# Out:
# GAP: Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) )

# %%
Abel = AbelianClosure( L )
# Out:
# GAP: AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )

# %%
G = Abel.G
# Out:
# GAP: <A projective object in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
A = ImageEmbedding( Abel.a )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
B = ImageEmbedding( Abel.b )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
C = ImageEmbedding( Abel.c )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
D = ImageEmbedding( Abel.d )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
∪,∩ = EmbeddingOfUnionSubobject, EmbeddingOfIntersectionSubobject
# Out:
# (GAP: <Operation "EmbeddingOfUnionSubobject">, GAP: <Operation "EmbeddingOfIntersectionSubobject">)

# %%
Φ₀ = ( A ∪ B ) ∩ ( C ∪ D )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
Ψ₀ = ( A ∩ C ) ∪ ( A ∩ D ) ∪ ( B ∩ C ) ∪ ( B ∩ D )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
IsDominating( Ψ₀, Φ₀ )
# Out:
# true

# %%
IsEqualAsSubobjects( Ψ₀, Φ₀ )
# Out:
# false

# %%
H₀ = HomologyObject( Ψ₀, CokernelProjection( Φ₀ ) )
# Out:
# GAP: <An object in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
IsZero( H₀ )
# Out:
# false

# %%
Φ₁ = ( A ∪ C ) ∩ ( B ∪ D )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
Ψ₁ = ( A ∩ B ) ∪ ( A ∩ D ) ∪ ( C ∩ B ) ∪ ( C ∩ D )
# Out:
# GAP: <A monomorphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
IsDominating( Ψ₁, Φ₁ )
# Out:
# true

# %%
IsEqualAsSubobjects( Ψ₁, Φ₁ )
# Out:
# false

# %%
H₁ = HomologyObject( Ψ₁, CokernelProjection( Φ₁ ) )
# Out:
# GAP: <An object in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
IsZero( H₁ )
# Out:
# false

# %%
HomStructure( H₀, H₁ )
# Out:
# GAP: <A row module over Q of rank 1>

# %%
iso = BasisOfExternalHom( H₀, H₁ )[1]
# Out:
# GAP: <A morphism in AbelianClosure( Algebroid( Q, FreeCategory( RightQuiver( "q(sa,sb,sc,sd,G)[a:sa->G,b:sb->G,c:sc->G,d:sd->G]" ) ) ) )>

# %%
IsIsomorphism( iso )
# Out:
# true

# %% [markdown]
# ---

# %%
F2 = HomalgRingOfIntegers( 2 )
# Out:
# GAP: GF(2)

# %%
Mat = MatrixCategory( F2 )
# Out:
# GAP: Category of matrices over GF(2)

# %%
GG = 4 / Mat
# Out:
# GAP: <A vector space object over GF(2) of dimension 4>

# %%
bas = BasisOfExternalHom( TensorUnit( Mat ), GG )
# Out:
# GAP: [ <A morphism in Category of matrices over GF(2)>, <A morphism in Category of matrices over GF(2)>, <A morphism in Category of matrices over GF(2)>, <A morphism in Category of matrices over GF(2)> ]

# %%
ForAll( bas, IsMonomorphism )
# Out:
# true

# %%
p,q,u,v = bas
# Out:
# GAP: [ <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)> ]

# %%
AA = u ∪ (v+p) ∪ (v+q)
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
BB = u ∪ v ∪ (p+q)
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
CC = p
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
DD = q
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
Display( ( AA ∪ CC ) ∩ ( BB ∪ DD ) )
# Out:
#  1 . . .
#  . 1 . .
#  . . 1 .
#  . . . 1
#
# A split monomorphism in Category of matrices over GF(2)

# %%
subobjects = SubobjectsOfGeneratedSublattice( GG, [ AA, BB, CC, DD ] )
# Out:
# GAP: [ <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)>, <A split monomorphism in Category of matrices over GF(2)> ]

# %%
Length( subobjects )
# Out:
# 10

# %%
ForAny( subobjects, IsZero )
# Out:
# true

# %%
ForAny( subobjects, IsEpimorphism )
# Out:
# true

# %%
ϕ₀ = ( AA ∪ BB ) ∩ ( CC ∪ DD )
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
ψ₀ = ( AA ∩ CC ) ∪ ( AA ∩ DD ) ∪ ( BB ∩ CC ) ∪ ( BB ∩ DD )
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
ϕ₁ = ( AA ∪ CC ) ∩ ( BB ∪ DD )
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
ψ₁ = ( AA ∩ BB ) ∪ ( AA ∩ DD ) ∪ ( CC ∩ BB ) ∪ ( CC ∩ DD )
# Out:
# GAP: <A split monomorphism in Category of matrices over GF(2)>

# %%
Position( subobjects, AA )
# Out:
# 1

# %%
Position( subobjects, BB )
# Out:
# 2

# %%
Position( subobjects, CC )
# Out:
# 3

# %%
Position( subobjects, DD )
# Out:
# 4

# %%
DigraphOfSubobjects( GG, subobjects )
# Out:
# GAP: <immutable digraph with 10 vertices, 14 edges>

# %%
Position( subobjects, ϕ₀ )
# Out:
# 6

# %%
Position( subobjects, ψ₀ )
# Out:
# 8

# %%
Position( subobjects, ϕ₁ )
# Out:
# 5

# %%
Position( subobjects, ψ₁ )
# Out:
# 7
