# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.4.7
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
TerminalObject( FinQuivers )
# Out:
# GAP: <An object in CategoryOfQuiversEnrichedOver( SkeletalFinSets )>

# %%
decorating_quiver = SubobjectClassifier( FinQuivers )
# Out:
# GAP: <An object in CategoryOfQuiversEnrichedOver( SkeletalFinSets )>

# %%
DecoratedFinQuivers =
  CategoryOfDecoratedQuivers( decorating_quiver,
    ## decoration_of_vertices
    [ "magenta", # 0
      "cyan" ],  # 1
    ## decoration_of_arrows
    [ "red",     # 0
      "brown",   # 1
      "orange",  # 2
      "blue",    # 3
      "green" ]  # 4
    )
# Out:
# GAP: CategoryOfDecoratedQuivers( decorating_quiver )

# %%
Slice = ModelingCategory( DecoratedFinQuivers )
# Out:
# GAP: A slice category of CategoryOfQuiversEnrichedOver( SkeletalFinSets )

# %%
BaseObject( Slice ) == decorating_quiver
# Out:
# true

# %%
B = TerminalObject( DecoratedFinQuivers )
# Out:
# GAP: <An object in CategoryOfDecoratedQuivers( decorating_quiver )>

# %%
Subobject( B, [0], [ 3, 4 ] )
# Out:
# GAP: <A monomorphism in CategoryOfDecoratedQuivers( decorating_quiver )>

# %%
dq1 = CreateDecoratedQuiver( DecoratedFinQuivers,
               [ 0, 1, 1, 1 ], # decoration of [ 0, 1, 2, 3 ]
               [ 0,0,0,  0,1,2,  1,0,1,  1,2,3,  2,3,4,  3,2,3 ] ## arrows_with_decoration
    )
# Out:
# GAP: <An object in CategoryOfDecoratedQuivers( decorating_quiver )>

# %%
IsWellDefined( dq1 )
# Out:
# true

# %%
Ω = SubobjectClassifier( DecoratedFinQuivers )
# Out:
# GAP: <An object in CategoryOfDecoratedQuivers( decorating_quiver )>
