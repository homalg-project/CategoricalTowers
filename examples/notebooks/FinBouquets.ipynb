# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.4.7
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %% [markdown]
# The category $\mathbf{FinBouquets}$ of finite bouquets:

# %%
FinBouquets
# Out:
# GAP: CategoryOfBouquetsEnrichedOver( SkeletalFinSets )

# %%
Display( FinBouquets )
# Out:
# A CAP category with name CategoryOfBouquetsEnrichedOver( SkeletalFinSets ):
#
# 68 primitive operations were used to derive 269 operations for this category which algorithmically
# * IsEquippedWithHomomorphismStructure
# * IsElementaryTopos

# %%
C = UnderlyingCategory( FinBouquets )
# Out:
# GAP: FreeCategory( RightQuiver( "q(V,L)[b:V->L]" ) )

# %%
Ĉ = ModelingCategory( FinBouquets )
# Out:
# GAP: FiniteCocompletion( FreeCategory( RightQuiver( "q(V,L)[b:V->L]" ) ) )

# %%
PSh = ModelingCategory( Ĉ )
# Out:
# GAP: PreSheaves( FreeCategory( RightQuiver( "q(V,L)[b:V->L]" ) ), SkeletalFinSets )

# %%
V = FinBouquets.V
# Out:
# GAP: <A projective object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
L = FinBouquets.L
# Out:
# GAP: <A projective object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
b = FinBouquets.b
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
T = TerminalObject( FinBouquets )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
T == L
# Out:
# true

# %%
M = CreateBouquet( 3, [ 1, 1, 1, 2 ] )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Display( M )
# Out:
# ( { 0, 1, 2 }, { 0 ↦ 1, 1 ↦ 1, 2 ↦ 1, 3 ↦ 2 } )

# %%
Colimit( [ V, V, V, L, L, L, L ], [ ] )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
N = Colimit( [ V, V, V, L, L, L, L ],
    [ [ 1, b, 3 ],
      [ 1, b, 4 ],
      [ 1, b, 5 ],
      [ 2, b, 6 ]
    ] )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
N == M
# Out:
# true

# %% [markdown]
# ---
# As we will see below, the law of excluded middle is not valid in $\mathbf{FinBouquets}$. Consequently, the (external) axiom of choice cannot be valid in $\mathbf{FinBouquets}$ either:

# %%
LL = Coproduct( L, L )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
L2 = CreateBouquet( 1, [ 0, 0 ] )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
ε = CreateBouquetMorphism( LL, [ 0, 0 ], [ 0, 1 ], L2 )
# Out:
# GAP: <A morphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
IsWellDefined( ε )
# Out:
# true

# %%
IsEpimorphism( ε )
# Out:
# true

# %%
IsSplitEpimorphism( ε )
# Out:
# false

# %%
Ω = SubobjectClassifier( FinBouquets )
# Out:
# GAP: <An object in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
subobjects = ListOfSubobjects( Ω );

# %%
#Visualize( DotVertexLabelledDigraph( DigraphOfSubobjects( Ω ) ) )

# %% [markdown]
# <img src="svg/SubobjectClassifierOfToposOfFinBouquets.svg" alt="drawing" width="200"/>

# %%
¬ = TruthMorphismOfNot( FinBouquets ); SubobjectOfClassifyingMorphism( PreCompose( ¬, ¬ ) )
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
LT = LawvereTierneySubobjects( FinBouquets ); Length( LT )
# Out:
# 4

# %%
LT[1]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
LT[2]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
LT[3]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
LT[4]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Ωs = LawvereTierneyEmbeddingsOfSubobjectClassifiers( FinBouquets );

# %%
Ωs[1]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Ωs[2]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Ωs[3]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Ωs[4]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
f = subobjects[1]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
A = subobjects[2]
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
notA = EmbeddingOfPseudoComplementSubobject( A )
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
pos = Position( subobjects, notA )
# Out:
# 7

# %%
notA == subobjects[pos]
# Out:
# true

# %%
A_or_notA = EmbeddingOfUnionSubobject( A, notA )
# Out:
# GAP: <A monomorphism in CategoryOfBouquetsEnrichedOver( SkeletalFinSets )>

# %%
Position( subobjects, A_or_notA )
# Out:
# 14
