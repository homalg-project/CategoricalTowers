22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3Cuse%20x%3D%2267.217889%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23m%22%2F%3E%3Cuse%20x%3D%2272.905023%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23l%22%2F%3E%3Cuse%20x%3D%2276.876602%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23d%22%2F%3E%3Cuse%20x%3D%2279.989706%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3Cuse%20x%3D%2283.531699%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23f%22%2F%3E%3Cuse%20x%3D%2287.503278%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%2291.474857%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3Cuse%20x%3D%2294.587962%22%20y%3D%226.911%22%20xlink%3Ahref%3D%22%23k%22%2F%3E%3C%2Fg%3E%3Cpath%20transform%3D%22matrix%281%2C0%2C0%2C-1%2C74.332%2C30.043%29%22%20d%3D%22m37.578-8.8281c-24.492-14.141-48.031-14.141-72.184-0.19922%22%20fill%3D%22none%22%20stroke%3D%22%23000%22%20stroke-miterlimit%3D%2210%22%20stroke-width%3D%22.39848%22%2F%3E%3Cpath%20transform%3D%22matrix%28-.86601%20-.49998%20-.49998%20.86601%2039.555%2038.969%29%22%20d%3D%22m-2.0698%202.3903c0.37655-1.4335%201.2188-2.111%202.0703-2.3907-0.84959-0.2785-1.6945-0.95575-2.0704-2.3906%22%20fill%3D%22none%22%20stroke%3D%22%23000%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20stroke-miterlimit%3D%2210%22%20stroke-width%3D%22.39848%22%2F%3E%3Cg%3E%3Cuse%20x%3D%2246.461%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23e%22%2F%3E%3Cuse%20x%3D%2250.959798%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%2254.931377%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3Cuse%20x%3D%2258.044482%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23f%22%2F%3E%3Cuse%20x%3D%2262.016061%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3Cuse%20x%3D%2265.558054%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23d%22%2F%3E%3Cuse%20x%3D%2268.671158%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23q%22%2F%3E%3Cuse%20x%3D%2271.141278%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23g%22%2F%3E%3Cuse%20x%3D%2275.541746%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23p%22%2F%3E%3Cuse%20x%3D%2277.797073%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23e%22%2F%3E%3Cuse%20x%3D%2282.288897%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23g%22%2F%3E%3Cuse%20x%3D%2286.689365%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23o%22%2F%3E%3Cuse%20x%3D%2291.089833%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23n%22%2F%3E%3Cuse%20x%3D%2294.631826%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23d%22%2F%3E%3Cuse%20x%3D%2297.74493%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%22101.71651%22%20y%3D%2256.663%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3C%2Fg%3E%3C%2Fsvg%3E">

# %% [markdown]
# If $F: \text{FreeCategory}(q) \to C$, then $F$ is uniquely determined by its
# restriction to the generating quiver $q$.
#
# $$
# \text{Hom}_{(\text{Cats})}(\text{FreeCategory}(q),C) \cong \text{Hom}_{(\text{Quivs})}(q,\text{ForgetfulFunctor}(C))
# $$
#
# We exploit this in our data structure, a functor
# $F:\text{FreeCategory}(q) \to C$ is internally defined on $q$ and
# extended to a morphism in $\text{FreeCategory}(q)$ when needed.
#
# More generally, if $B=\langle q \rangle$ is the free category construction in some categorical doctrine,
# then functors need only be defined on the generating quiver $q$.
#
# The notion of "generation" depends on the forgetful functor.

# %% [markdown]
# <img alt="diagram" width="1000px" src="data:image/svg+xml,%3Csvg%20width%3D%22362.46pt%22%20height%3D%2262.076pt%22%20version%3D%221.1%22%20viewBox%3D%220%200%20362.46%2062.076%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%3E%3Cdefs%3E%3Csymbol%20id%3D%22k%22%20overflow%3D%22visible%22%3E%3Cpath%20d%3D%22m3
22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23m%22%2F%3E%3Cuse%20x%3D%22274.663699%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23af%22%2F%3E%3Cuse%20x%3D%22278.633186%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3Cuse%20x%3D%22282.175179%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23l%22%2F%3E%3Cuse%20x%3D%22287.862313%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23g%22%2F%3E%3Cuse%20x%3D%22290.11764%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%22294.089219%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23v%22%2F%3E%3Cuse%20x%3D%22297.245561%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23e%22%2F%3E%3Cuse%20x%3D%22301.646029%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3Cuse%20x%3D%22304.759133%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3Cuse%20x%3D%22308.301126%22%20y%3D%228.577%22%20xlink%3Ahref%3D%22%23u%22%2F%3E%3Cuse%20x%3D%22314.419%22%20y%3D%225.57%22%20xlink%3Ahref%3D%22%23ac%22%2F%3E%3C%2Fg%3E%3Cpath%20transform%3D%22matrix%281%200%200%20-1%20182.89%2031.154%29%22%20d%3D%22m142.45-8.8265c-26.344-15.211-51.66-15.211-77.66-0.19922%22%20fill%3D%22none%22%20stroke%3D%22%23000%22%20stroke-miterlimit%3D%2210%22%20stroke-width%3D%22.39848%22%2F%3E%3Cpath%20transform%3D%22matrix%28-.86601%20-.49998%20-.49998%20.86601%20247.51%2040.08%29%22%20d%3D%22m-2.0713%202.3921c0.3785-1.4369%201.2207-2.1144%202.0703-2.3907-0.84959-0.2785-1.6926-0.95913-2.0704-2.3906%22%20fill%3D%22none%22%20stroke%3D%22%23000%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20stroke-miterlimit%3D%2210%22%20stroke-width%3D%22.39848%22%2F%3E%3Cg%3E%3Cuse%20x%3D%22257.15%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23f%22%2F%3E%3Cuse%20x%3D%22261.648798%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%22265.620377%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3Cuse%20x%3D%22268.733482%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23h%22%2F%3E%3Cuse%20x%3D%22272.705061%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23b%22%2F%3E%3Cuse%20x%3D%22276.247054%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23d%22%2F%3E%3Cuse%20x%3D%22279.360158%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23o%22%2F%3E%3Cuse%20x%3D%22281.830278%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23e%22%2F%3E%3Cuse%20x%3D%22286.230746%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23g%22%2F%3E%3Cuse%20x%3D%22288.486073%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23f%22%2F%3E%3Cuse%20x%3D%22292.977898%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23e%22%2F%3E%3Cuse%20x%3D%22297.378365%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23i%22%2F%3E%3Cuse%20x%3D%22301.778833%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23n%22%2F%3E%3Cuse%20x%3D%22305.320826%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23d%22%2F%3E%3Cuse%20x%3D%22308.43393%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23c%22%2F%3E%3Cuse%20x%3D%22312.40551%22%20y%3D%2258.575%22%20xlink%3Ahref%3D%22%23a%22%2F%3E%3C%2Fg%3E%3C%2Fsvg%3E">

# %% [markdown]
# Let $D: I \to C$ be a functor. A __cone__
# of $D$ consists of the following data:
# * An object $S \in C$;
# * A dependent function $s$ mapping an object $i \in I$
# to a morphism $s(i): S \to D(i)$ with the specification: For all
# $i, j \in I, \iota: i \to j$, we have $D(\iota) \circ s(i)=s(j)$.
#
# The __weak limit__ is an algorithm that takes as input a functor
# $D: I \to C$ where $I$ is called a diagram category
# and outputs the following data:
#
# (1) A cone of $D$ given by the data
# $\left(\lim D, \{\lambda(i):\lim D \to D(i)\}_{i\in I}\right)$;
#
# (2) A dependent function $u$ mapping every cone $\tau =
# (T,\{\tau(i):T \to D(i)\}_{i\in I})$ to a morphism
# $u(\tau):T \to \lim D$ with the specification:
# $\lambda(i) \circ u(\tau) = \tau(i)$ for all $i \in I$.
#
# A weak limit is called __limit__, if for any other
# dependent function $v$ satisfying (2), we have $u=v$.

# %% [markdown]
# First we load the Julia package `CapAndHomalg` giving access to the $\texttt{GAP}$ software projects $\mathtt{QPA2}$, $\mathtt{CAP}$ and $\mathtt{homalg}$:

# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.3.1
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %% [markdown]
# Then load the $\mathtt{CAP}$-based package $\mathtt{FunctorCategories}$:

# %%
LoadPackage("FunctorCategories")

# %% [markdown]
# The field of rationals:

# %%
ℚ = HomalgFieldOfRationals()
# Out:
# GAP: Q

# %% [markdown]
# Define the quiver $q$ with vertices $x,y,z,w$ and arrows $a,b,c,d$:

# %%
q = RightQuiver("q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w]")
# Out:
# GAP: q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w]

# %% [markdown]
# $D$ is defined to be the free category generated by the quiver $q$:

# %%
D = FreeCategory(q)
# Out:
# GAP: Category freely generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w]

# %% [markdown]
# Define the quotient category of $E$ by the relation $bc = bd$. Such relations can only express equalities between parallel morphisms:

# %%
E = D / [[D.bc, D.bd]]
# Out:
# GAP: Category generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w] with relations [ b*c = b*d ]

# %% [markdown]
# Construct the $\mathbb Q$-linear closure category $L$ of the finitely presented category $E$:

# %%
L = ℚ[E]
# Out:
# GAP: Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w]

# %% [markdown]
# Relations in linear categories are generators of a two-sided ideal. We consider the relation $abc=0$:

# %%
B = L / [L.abc]
# Out:
# GAP: Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w]

# %% [markdown]
# The relations of $B$ are the relations defined for the category $E$ combined with the relations for the linear category $L$:

# %%
UnderlyingQuiverAlgebra(B)
# Out:
# GAP: (Q * q) / [ -1*(b*d) + 1*(b*c), 1*(a*b*c) ]

# %% [markdown]
# Construct the category $A$ of matrices over $\mathbb Q$:

# %%
A = MatrixCategory(ℚ)
# Out:
# GAP: Category of matrices over Q

# %% [markdown]
# Construct the category $H$ of functors from $B$ to $A$:

# %%
H = FunctorCategory(B, A)
# Out:
# GAP: FunctorCategory( Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w] -> Category of matrices over Q )

# %% [markdown]
# Define the matrices which will be the images of the generating morphisms of $B$ (corresponding to the morphisms of $q$) under a functor in $H$:

# %%
mat_a = [[2,3,1], [1,0,-1]]
# Out:
# 2-element Vector{Vector{Int64}}:
#  [2, 3, 1]
#  [1, 0, -1]

# %%
mat_b = [[2,0,-1,7], [3,2,1,5], [-2,5,6,-7]]
# Out:
# 3-element Vector{Vector{Int64}}:
#  [2, 0, -1, 7]
#  [3, 2, 1, 5]
#  [-2, 5, 6, -7]

# %%
mat_c = [[-8],[2],[0],[3]] #mat_c = SyzygiesOfColumns(HomalgMatrix(mat_a, ℚ) * HomalgMatrix(mat_b, ℚ))
# Out:
# 4-element Vector{Vector{Int64}}:
#  [-8]
#  [2]
#  [0]
#  [3]

# %%
mat_d = [[-14],[35],[-33],[0]] #mat_d = LeftDivide(HomalgMatrix(mat_b, ℚ), HomalgMatrix(mat_b, ℚ) * HomalgMatrix(mat_c, ℚ))
# Out:
# 4-element Vector{Vector{Int64}}:
#  [-14]
#  [35]
#  [-33]
#  [0]

# %% [markdown]
# We now turn these matrices into morphisms in the matrix category $A$:

# %%
α = mat_a / A
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %%
Display(α)
# Out:
# [ [   2,   3,   1 ],
#   [   1,   0,  -1 ] ]
#
# A morphism in Category of matrices over Q

# %%
β = mat_b / A
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %%
Display(β)
# Out:
# [ [   2,   0,  -1,   7 ],
#   [   3,   2,   1,   5 ],
#   [  -2,   5,   6,  -7 ] ]
#
# A morphism in Category of matrices over Q

# %%
γ = mat_c / A
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %%
Display(γ)
# Out:
# [ [  -8 ],
#   [   2 ],
#   [   0 ],
#   [   3 ] ]
#
# A morphism in Category of matrices over Q

# %%
δ = mat_d / A
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %% [markdown]
# Using the above adjunctions, we can define a functor from $B$ to $A$ by defining a functor from the generating quiver $q$ to $A$ fulfilling the relations of $B$:

# %%
Vertices(q)
# Out:
# GAP: [ (x), (y), (z), (w) ]

# %%
Arrows(q)
# Out:
# GAP: [ (a), (b), (c), (d) ]

# %% [markdown]
# Define the functor $F$ by the maps $(x \mapsto 2, y \mapsto 3, z \mapsto 4, w \mapsto 1)$ and
# $(a \mapsto \alpha, b \mapsto \beta, c \mapsto \gamma, d \mapsto \delta)$:

# %%
F = AsObjectInFunctorCategory(B, [2,3,4,1], [α,β,γ,δ])
# Out:
# GAP: <(x)->2, (y)->3, (z)->4, (w)->1; (a)->2x3, (b)->3x4, (c)->4x1, (d)->4x1>

# %% [markdown]
# The range of the functor $F$ is exactly the category $A$ from above:

# %%
Range(F) === A
# Out:
# true

# %% [markdown]
# Similarly, the functor $F$ is an object in the functor category $H$:

# %%
CapCategory(F) === H
# Out:
# true

# %% [markdown]
# The object constructor also accepts a list of matrices which are, as above, used to define morphisms in the matrix category of the underlying field:

# %%
F = AsObjectInFunctorCategory(B, [2, 3, 4, 1], [mat_a, mat_b, mat_c, mat_d])
# Out:
# GAP: <(x)->2, (y)->3, (z)->4, (w)->1; (a)->2x3, (b)->3x4, (c)->4x1, (d)->4x1>

# %% [markdown]
# The range of $F$ ist still $A$:

# %%
Range(F) === A
# Out:
# true

# %% [markdown]
# $F$ is still an object of $H$:

# %%
CapCategory(F) === H
# Out:
# true

# %% [markdown]
# We can apply $F$ to objects of $B$:

# %%
F(B.x)
# Out:
# GAP: <A vector space object over Q of dimension 2>

# %% [markdown]
# We can also apply $F$ to morphisms of $B$:

# %%
F(B.a)
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %%
Display(F(B.a))
# Out:
# [ [   2,   3,   1 ],
#   [   1,   0,  -1 ] ]
#
# A morphism in Category of matrices over Q

# %%
Display(F(B.b))
# Out:
# [ [   2,   0,  -1,   7 ],
#   [   3,   2,   1,   5 ],
#   [  -2,   5,   6,  -7 ] ]
#
# A morphism in Category of matrices over Q

# %% [markdown]
# Now we check the functoriality manually on an instance:

# %%
Display(F(B.ab))
# Out:
# [ [  11,  11,   7,  22 ],
#   [   4,  -5,  -7,  14 ] ]
#
# A morphism in Category of matrices over Q

# %%
Display(PreCompose(F(B.a), F(B.b)))
# Out:
# [ [  11,  11,   7,  22 ],
#   [   4,  -5,  -7,  14 ] ]
#
# A morphism in Category of matrices over Q

# %%
PreCompose(F(B.a), F(B.b)) == F(B.ab)
# Out:
# true

# %% [markdown]
# Then we check that $F$ preserves the relations of $B$:

# %%
F(B.bc) == F(B.bd)
# Out:
# true

# %%
F(B.abc)
# Out:
# GAP: <A zero morphism in Category of matrices over Q>

# %%
F(B.abd)
# Out:
# GAP: <A zero morphism in Category of matrices over Q>

# %% [markdown]
# The following command checks the functoriality of $F$ and that it preserves the relations of $B$:

# %%
IsWellDefined(F)
# Out:
# true

# %% [markdown]
# We now define a natural endomorphism $\eta:F \Rightarrow F$ by specifying its components for the four objects $x,y,z,w$ which are morphisms in $A$ defined by the following matrices:

# %%
mat_x = [[49//3,49//3],[-49//3,-49//3]]
# Out:
# 2-element Vector{Vector{Rational{Int64}}}:
#  [49//3, 49//3]
#  [-49//3, -49//3]

# %%
mat_y = [[-44,28,-12],[44,-28,12],[5,77,-12]]
# Out:
# 3-element Vector{Vector{Int64}}:
#  [-44, 28, -12]
#  [44, -28, 12]
#  [5, 77, -12]

# %%
mat_z = [[-84,0,0,0],[0,-84,0,0],[57,102,0,84],[35,14,0,0]]
# Out:
# 4-element Vector{Vector{Int64}}:
#  [-84, 0, 0, 0]
#  [0, -84, 0, 0]
#  [57, 102, 0, 84]
#  [35, 14, 0, 0]

# %%
mat_w = [[-84]]
# Out:
# 1-element Vector{Vector{Int64}}:
#  [-84]

# %%
η = AsMorphismInFunctorCategory(F, [mat_x / A, mat_y / A, mat_z / A, mat_w / A], F)
# Out:
# GAP: <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>

# %% [markdown]
# The components of $\eta$ can be accessed as follows:

# %%
η(B.x)
# Out:
# GAP: <A morphism in Category of matrices over Q>

# %%
Display(η(B.x))
# Out:
# [ [   49/3,   49/3 ],
#   [  -49/3,  -49/3 ] ]
#
# A morphism in Category of matrices over Q

# %% [markdown]
# Check whether $\eta$ is indeed a natural transformation:

# %%
IsWellDefined(η)
# Out:
# true

# %% [markdown]
# Checking this manually would mean to check:

# %%
PreCompose(F(B.a), η(B.y)) == PreCompose(η(B.x), F(B.a))
# Out:
# true

# %%
PreCompose(F(B.b), η(B.z)) == PreCompose(η(B.y), F(B.b))
# Out:
# true

# %%
PreCompose(F(B.c), η(B.w)) == PreCompose(η(B.z), F(B.c))
# Out:
# true

# %%
PreCompose(F(B.d), η(B.w)) == PreCompose(η(B.z), F(B.d))
# Out:
# true

# %% [markdown]
# We can even compute a basis of the vector space of natural endomorphisms of $F$:

# %%
endF = BasisOfExternalHom(F,F)
# Out:
# GAP: [ <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>, <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1> ]

# %% [markdown]
# The above natural transformation $\eta$ has the following coefficients with respect to the above computed basis:

# %%
c = CoefficientsOfMorphism(η)
# Out:
# GAP: [ 0, 0, 0, 0, 0, 84, 0, 0, -84 ]

# %% [markdown]
# Indeed:

# %%
Sum(ListN(c, endF, GapObj((a, m) -> a*m))) == η
# Out:
# true

# %% [markdown]
# The category of functors inherits all finite limits and finite colimits from its target category, which in our case is Abelian. Below, we compute several categorical operations which exist in Abelian categories:

# %%
ker = KernelObject(η)
# Out:
# GAP: <(x)->1, (y)->1, (z)->1, (w)->0; (a)->1x1, (b)->1x1, (c)->1x0, (d)->1x0>

# %%
Display(ker)
# Out:
# An object in FunctorCategory( Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w] -> Category of matrices over Q ) defined by the following data:
#
#
# Image of <(x)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(y)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(z)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(w)>:
# A vector space object over Q of dimension 0
#
#
# Image of (x)-[{ 1*(a) }]->(y):
# [ [  3 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (y)-[{ 1*(b) }]->(z):
# [ [  12 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(c) }]->(w):
# (an empty 1 x 0 matrix)
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(d) }]->(w):
# (an empty 1 x 0 matrix)
#
# A morphism in Category of matrices over Q

# %%
coker = CokernelObject(η)
# Out:
# GAP: <(x)->1, (y)->1, (z)->1, (w)->0; (a)->1x1, (b)->1x1, (c)->1x0, (d)->1x0>

# %%
Display(coker)
# Out:
# An object in FunctorCategory( Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w] -> Category of matrices over Q ) defined by the following data:
#
#
# Image of <(x)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(y)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(z)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(w)>:
# A vector space object over Q of dimension 0
#
#
# Image of (x)-[{ 1*(a) }]->(y):
# [ [  -7/6 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (y)-[{ 1*(b) }]->(z):
# [ [  6 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(c) }]->(w):
# (an empty 1 x 0 matrix)
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(d) }]->(w):
# (an empty 1 x 0 matrix)
#
# A morphism in Category of matrices over Q

# %%
im = ImageObject(η)
# Out:
# GAP: <(x)->1, (y)->2, (z)->3, (w)->1; (a)->1x2, (b)->2x3, (c)->3x1, (d)->3x1>

# %%
Display(im)
# Out:
# An object in FunctorCategory( Algebroid generated by the right quiver q(x,y,z,w)[a:x->y,b:y->z,c:z->w,d:z->w] -> Category of matrices over Q ) defined by the following data:
#
#
# Image of <(x)>:
# A vector space object over Q of dimension 1
#
#
# Image of <(y)>:
# A vector space object over Q of dimension 2
#
#
# Image of <(z)>:
# A vector space object over Q of dimension 3
#
#
# Image of <(w)>:
# A vector space object over Q of dimension 1
#
#
# Image of (x)-[{ 1*(a) }]->(y):
# [ [  3,  0 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (y)-[{ 1*(b) }]->(z):
# [ [   5,   2,  12 ],
#   [  10,   5,  35 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(c) }]->(w):
# [ [  -8 ],
#   [   2 ],
#   [   3 ] ]
#
# A morphism in Category of matrices over Q
#
#
# Image of (z)-[{ 1*(d) }]->(w):
# [ [  -14 ],
#   [   35 ],
#   [    0 ] ]
#
# A morphism in Category of matrices over Q

# %%
ι = KernelEmbedding(η)
# Out:
# GAP: <(x)->1x2, (y)->1x3, (z)->1x4, (w)->0x1>

# %%
η_2 = PreCompose(η, η)
# Out:
# GAP: <(x)->2x2, (y)->3x3, (z)->4x4, (w)->1x1>

# %%
IsZero(η_2)
# Out:
# false

# %% [markdown]
# We expect the composition of $\iota$ and $\eta_2 := \eta^2$ to be zero, since the composition of $\iota$ and $\eta$ is zero:

# %%
IsZero(PreCompose(ι,η_2))
# Out:
# true

# %%
ι_2 = KernelEmbedding(η_2)
# Out:
# GAP: <(x)->2x2, (y)->2x3, (z)->2x4, (w)->0x1>

# %% [markdown]
# We expect the kernel embedding $\iota$ of $\eta$ to be liftable along the dominating kernel embedding $\iota_2$ of $\eta_2 := \eta^2$:

# %%
IsLiftable(ι, ι_2)
# Out:
# true

# %% [markdown]
# Now we compute an explicit lift:

# %%
λ = Lift(ι, ι_2)
# Out:
# GAP: <(x)->1x2, (y)->1x2, (z)->1x2, (w)->0x0>

# %% [markdown]
# In fact, the lift is unique since $\iota_2$ is a monomorphism (beware of the change of syntax!):

# %%
μ = LiftAlongMonomorphism(ι_2, ι)
# Out:
# GAP: <(x)->1x2, (y)->1x2, (z)->1x2, (w)->0x0>

# %%
λ == μ
# Out:
# true

# %% [markdown]
# We do not necessarily expect $\iota_2$ to be liftable along $\iota$:

# %%
IsLiftable(ι_2, ι)
# Out:
# false
