# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.4.0
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FreydCategoriesForCAP" )

# %%
LoadPackage( "SubcategoriesForCAP" )

# %%
LoadPackage( "Locales" )

# %%
LoadPackage( "LazyCategories" )

# %%
Q = HomalgFieldOfRationalsInSingular( )
# Out:
# GAP: Q

# %%
R = Q["x,y"]
# Out:
# GAP: Q[x,y]

# %%
K = HomalgMatrix( "[ x, -x ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
J = HomalgMatrix( "[ x, y ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
I = KroneckerMat( K, J )
# Out:
# GAP: <An unevaluated 4 x 1 matrix over an external ring>

# %%
P = CategoryOfRows( R )
# Out:
# GAP: Rows( Q[x,y] )

# %%
P = LazyCategory( P, show_evaluation = true, primitive_operations = true )
# Out:
# GAP: LazyCategory( Rows( Q[x,y] ) )

# %%
I = I / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( I, "I" ); SetLabel( Source( I ), "R^i" )

# %%
R = Range( I )
# Out:
# GAP: <An evaluated object in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( R, "R" )

# %%
J = J / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( J, "J" ); SetLabel( Source( J ), "R^j" )

# %%
K = K / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
S = SliceCategoryOverTensorUnit( P )
# Out:
# GAP: SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) )

# %%
L = PosetOfCategory( S )
# Out:
# GAP: Poset( SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) ) )

# %%
I = I / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
J = J / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
K = K / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
IqJ = InternalHom( J, I )
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <A morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
Visualize( UnderlyingMorphism( UnderlyingCell( IqJ ) ) )

# %%
K == IqJ
# Out:
# 1.      -> evaluating in Rows( Q[x,y] ).........................: ProjectionOfBiasedWeakFiberProductWithGivenBiasedWeakFiberProduct
# 2.       -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 3.       -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 4.        -> evaluating in Rows( Q[x,y] ).........................: Lift
# 5.        -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 5.        <- evaluated in Rows( Q[x,y] ).........................: IdentityMorphism
# 6.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 7.        -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 8.         -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 9.         -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 10.        -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 11.        -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 12.        -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 13.        -> evaluating in Rows( Q[x,y] ).........................: DualOnObjects
# 13.        <- evaluated in Rows( Q[x,y] ).........................: DualOnObjects
# 12.        <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 11.        <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 14.        -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 14.        <- evaluated in Rows( Q[x,y] ).........................: IdentityMorphism
# 10.        <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 15.        -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 16.         -> evaluating in Rows( Q[x,y] ).........................: BraidingWithGivenTensorProducts
# 17.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 17.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 16.         <- evaluated in Rows( Q[x,y] ).........................: BraidingWithGivenTensorProducts
# 18.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 18.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 15.        <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 9.         <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 19.         -> evaluating in Rows( Q[x,y] ).........................: AssociatorLeftToRightWithGivenTensorProducts
# 20.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 20.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 19.         <- evaluated in Rows( Q[x,y] ).........................: AssociatorLeftToRightWithGivenTensorProducts
# 8.         <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 21.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 22.         -> evaluating in Rows( Q[x,y] ).........................: EvaluationForDualWithGivenTensorProduct
# 22.         <- evaluated in Rows( Q[x,y] ).........................: EvaluationForDualWithGivenTensorProduct
# 23.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 23.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 21.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 7.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 24.         -> evaluating in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 24.         <- evaluated in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 6.        <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 4.        <- evaluated in Rows( Q[x,y] ).........................: Lift
# 25.         -> evaluating in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 25.         <- evaluated in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 3.       <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 26.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 27.         -> evaluating in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 28.         -> evaluating in Rows( Q[x,y] ).........................: DualOnObjects
# 28.         <- evaluated in Rows( Q[x,y] ).........................: DualOnObjects
# 27.         <- evaluated in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 29.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 29.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 26.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 2.       <- evaluated in Rows( Q[x,y] ).........................: PreCompose
# 30.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 31.         -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 31.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 32.          -> evaluating in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 33.          -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 33.          <- evaluated in Rows( Q[x,y] ).........................: IdentityMorphism
# 32.          <- evaluated in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 30.         <- evaluated in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 34.          -> evaluating in Rows( Q[x,y] ).........................: BiasedWeakFiberProduct
# 34.          <- evaluated in Rows( Q[x,y] ).........................: BiasedWeakFiberProduct
# 1.      <- evaluated in Rows( Q[x,y] ).........................: ProjectionOfBiasedWeakFiberProductWithGivenBiasedWeakFiberProduct
# true
