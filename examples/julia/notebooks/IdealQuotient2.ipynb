# %%
using HomalgProject
# Out:
# HomalgProject v0.4.11
# Imported OSCAR's components GAP, Nemo, and Singular
# Type: ?HomalgProject for more information

# %%
LoadPackage( "FreydCategoriesForCAP" )

# %%
LoadPackage( "SubcategoriesForCAP" )

# %%
LoadPackage( "Locales" )

# %%
LoadPackage( "LazyCategories" )

# %%
Q = HomalgFieldOfRationalsInSingular( )
# Out:
# GAP: Q

# %%
R = Q["x,y"]
# Out:
# GAP: Q[x,y]

# %%
K = HomalgMatrix( "[ x, -x ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
J = HomalgMatrix( "[ x, y ]", 2, 1, R )
# Out:
# GAP: <A 2 x 1 matrix over an external ring>

# %%
I = KroneckerMat( K, J )
# Out:
# GAP: <An unevaluated 4 x 1 matrix over an external ring>

# %%
P = CategoryOfRows( R )
# Out:
# GAP: Rows( Q[x,y] )

# %%
P = LazyCategory( P, primitive_operations = true, show_evaluation = true )
# Out:
# GAP: LazyCategory( Rows( Q[x,y] ) )

# %%
I = I / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( I, "I" ); SetLabel( Source( I ), "R^i" )

# %%
R = Range( I )
# Out:
# GAP: <An evaluated object in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( R, "R" )

# %%
J = J / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
SetLabel( J, "J" ); SetLabel( Source( J ), "R^j" )

# %%
K = K / P
# Out:
# GAP: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
S = SliceCategoryOverTensorUnit( P )
# Out:
# GAP: SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) )

# %%
L = PosetOfCategory( S )
# Out:
# GAP: Poset( SliceCategoryOverTensorUnit( LazyCategory( Rows( Q[x,y] ) ) ) )

# %%
I = I / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
J = J / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
K = K / S / L
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <An evaluated morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
IqJ = InternalHom( J, I )
# Out:
# GAP: An object in the poset given by: An object in the slice category given by: <A morphism in LazyCategory( Rows( Q[x,y] ) )>

# %%
VisualizeInJulia( UnderlyingMorphism( UnderlyingCell( IqJ ) ) )

# %%
K == IqJ
# Out:
# 1.	-> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 2.	 -> evaluating in Rows( Q[x,y] ).........................: WeakKernelEmbeddingWithGivenWeakKernelObject
# 3.	 -> evaluating in Rows( Q[x,y] ).........................: AdditionForMorphisms
# 4.	  -> evaluating in Rows( Q[x,y] ).........................: UniversalMorphismIntoDirectSumWithGivenDirectSum
# 5.	  -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 6.	  -> evaluating in Rows( Q[x,y] ).........................: DualOnObjects
# 6.	  <- evaluated  in Rows( Q[x,y] ).........................: DualOnObjects
# 5.	  <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 7.	  -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 8.	   -> evaluating in Rows( Q[x,y] ).........................: ProjectionInFactorOfDirectSumWithGivenDirectSum
# 9.	   -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 9.	   <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 10.	   -> evaluating in Rows( Q[x,y] ).........................: DirectSum
# 10.	   <- evaluated  in Rows( Q[x,y] ).........................: DirectSum
# 8.	   <- evaluated  in Rows( Q[x,y] ).........................: ProjectionInFactorOfDirectSumWithGivenDirectSum
# 11.	   -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 12.	   -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 13.	   -> evaluating in Rows( Q[x,y] ).........................: Colift
# 14.	   -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 15.	   -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 16.	    -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 17.	    -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 18.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 19.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 20.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 21.	    -> evaluating in Rows( Q[x,y] ).........................: DualOnObjects
# 21.	    <- evaluated  in Rows( Q[x,y] ).........................: DualOnObjects
# 20.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 19.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 22.	    -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 22.	    <- evaluated  in Rows( Q[x,y] ).........................: IdentityMorphism
# 23.	    -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 23.	    <- evaluated  in Rows( Q[x,y] ).........................: IdentityMorphism
# 18.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 24.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 25.	    -> evaluating in Rows( Q[x,y] ).........................: BraidingWithGivenTensorProducts
# 26.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 26.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 25.	    <- evaluated  in Rows( Q[x,y] ).........................: BraidingWithGivenTensorProducts
# 27.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 27.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 24.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 17.	    <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 28.	    -> evaluating in Rows( Q[x,y] ).........................: AssociatorLeftToRightWithGivenTensorProducts
# 29.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 29.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 28.	    <- evaluated  in Rows( Q[x,y] ).........................: AssociatorLeftToRightWithGivenTensorProducts
# 16.	    <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 30.	    -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 31.	    -> evaluating in Rows( Q[x,y] ).........................: EvaluationForDualWithGivenTensorProduct
# 31.	    <- evaluated  in Rows( Q[x,y] ).........................: EvaluationForDualWithGivenTensorProduct
# 32.	     -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 32.	     <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnObjects
# 30.	    <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 15.	   <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 33.	     -> evaluating in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 33.	     <- evaluated  in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 14.	   <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 34.	     -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 34.	     <- evaluated  in Rows( Q[x,y] ).........................: IdentityMorphism
# 13.	   <- evaluated  in Rows( Q[x,y] ).........................: Colift
# 35.	     -> evaluating in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 35.	     <- evaluated  in Rows( Q[x,y] ).........................: RightUnitorWithGivenTensorProduct
# 12.	   <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 36.	     -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 37.	     -> evaluating in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 37.	     <- evaluated  in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 36.	     <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 11.	   <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 7.	  <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 4.	  <- evaluated  in Rows( Q[x,y] ).........................: UniversalMorphismIntoDirectSumWithGivenDirectSum
# 38.	     -> evaluating in Rows( Q[x,y] ).........................: AdditiveInverseForMorphisms
# 39.	     -> evaluating in Rows( Q[x,y] ).........................: UniversalMorphismIntoDirectSumWithGivenDirectSum
# 40.	     -> evaluating in Rows( Q[x,y] ).........................: PreCompose
# 41.	     -> evaluating in Rows( Q[x,y] ).........................: ProjectionInFactorOfDirectSumWithGivenDirectSum
# 41.	     <- evaluated  in Rows( Q[x,y] ).........................: ProjectionInFactorOfDirectSumWithGivenDirectSum
# 42.	     -> evaluating in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 43.	     -> evaluating in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 44.	     -> evaluating in Rows( Q[x,y] ).........................: IdentityMorphism
# 44.	     <- evaluated  in Rows( Q[x,y] ).........................: IdentityMorphism
# 43.	     <- evaluated  in Rows( Q[x,y] ).........................: DualOnMorphismsWithGivenDuals
# 42.	     <- evaluated  in Rows( Q[x,y] ).........................: TensorProductOnMorphismsWithGivenTensorProducts
# 40.	     <- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# 39.	     <- evaluated  in Rows( Q[x,y] ).........................: UniversalMorphismIntoDirectSumWithGivenDirectSum
# 38.	     <- evaluated  in Rows( Q[x,y] ).........................: AdditiveInverseForMorphisms
# 3.	 <- evaluated  in Rows( Q[x,y] ).........................: AdditionForMorphisms
# 45.	     -> evaluating in Rows( Q[x,y] ).........................: WeakKernelObject
# 45.	     <- evaluated  in Rows( Q[x,y] ).........................: WeakKernelObject
# 2.	 <- evaluated  in Rows( Q[x,y] ).........................: WeakKernelEmbeddingWithGivenWeakKernelObject
# 1.	<- evaluated  in Rows( Q[x,y] ).........................: PreCompose
# true
