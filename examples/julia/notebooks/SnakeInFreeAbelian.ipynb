# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.3.1
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "Algebroid" )

# %%
q = RightQuiver( "q(4)[a:1->2,b:2->3,c:3->4]" )
# Out:
# GAP: q(4)[a:1->2,b:2->3,c:3->4]

# %%
Fq = FreeCategory( q )
# Out:
# GAP: Category freely generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4]

# %%
ℤ = HomalgRingOfIntegers( )
# Out:
# GAP: Z

# %%
ℤq = ℤ[Fq]
# Out:
# GAP: Algebroid over Z freely generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4]

# %%
A = ℤq / [ ℤq.abc ]
# Out:
# GAP: Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4]

# %%
LoadPackage( "FreydCategoriesForCAP" )

# %%
A_add = AdditiveClosure( A )
# Out:
# GAP: Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] )

# %%
A_abel = AdelmanCategory( A_add )
# Out:
# GAP: Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) )

# %%
LoadPackage( "LazyCategories" )

# %%
Lazy = LazyCategory( A_abel, show_evaluation = true )
# Out:
# GAP: LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )

# %%
a = A.a / A_add / A_abel / Lazy
# Out:
# GAP: <An evaluated morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
b = A.b / A_add / A_abel / Lazy
# Out:
# GAP: <An evaluated morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
c = A.c / A_add / A_abel / Lazy
# Out:
# GAP: <An evaluated morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
SetLabel( Source( a ), "1" )
SetLabel( Source( b ), "2" )
SetLabel( Range( b ), "3" )
SetLabel( Range( c ), "4" )

# %%
d = CokernelProjection( a )
# Out:
# GAP: <An epimorphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
e = CokernelColift( a, PreCompose( b, c ) )
# Out:
# GAP: <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
f = KernelEmbedding( e )
# Out:
# GAP: <A monomorphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
g = KernelEmbedding( c )
# Out:
# GAP: <A monomorphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
h = KernelLift( c, PreCompose( a, b ) )
# Out:
# GAP: <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
i = CokernelProjection( h )
# Out:
# GAP: <An epimorphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
LoadPackage( "GeneralizedMorphismsForCAP" )

# %%
SwitchGeneralizedMorphismStandard( g"cospan" )

# %%
ff = AsGeneralizedMorphism( f )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
dd = AsGeneralizedMorphism( d )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
bb = AsGeneralizedMorphism( b )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
gg = AsGeneralizedMorphism( g )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
ii = AsGeneralizedMorphism( i )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
ss = PreCompose( [ ff, PseudoInverse( dd ), bb, PseudoInverse( gg ), ii ] )
# Out:
# GAP: <A morphism in Generalized morphism category of LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) ) by cospan>

# %%
s = HonestRepresentative( ss )
# Out:
# GAP: <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
Visualize( s )

# %%
sO = GenesisOfCellOperation( s )
# Out:
# GAP: "PreCompose"

# %%
sA = GenesisOfCellArguments( s )
# Out:
# GAP: [ <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>, <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )> ]

# %%
GenesisOfCellOperation( sA[1] )
# Out:
# GAP: "InjectionOfCofactorOfPushoutWithGivenPushout"

# %%
GenesisOfCellArguments( sA[1] )
# Out:
# GAP: [ [ <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>, <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )> ], 1, <An object in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )> ]

# %%
GenesisOfCellOperation( sA[2] )
# Out:
# GAP: "InverseForMorphisms"

# %%
GenesisOfCellArguments( sA[2] )
# Out:
# GAP: [ <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )> ]

# %%
HasGenesisOfCellOperation( a )
# Out:
# false

# %%
HasGenesisOfCellArguments( a )
# Out:
# false

# %%
j = KernelObjectFunctorial( b, d, e )
# Out:
# GAP: <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
k = CokernelObjectFunctorial( h, g, b )
# Out:
# GAP: <A morphism in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
HK = HomologyObject( j, s )
# Out:
# GAP: <An object in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>

# %%
HC = HomologyObject( s, k )
# Out:
# GAP: <An object in LazyCategory( Adelman category( Additive closure( Algebroid generated by the right quiver q(4)[a:1->2,b:2->3,c:3->4] ) ) )>
